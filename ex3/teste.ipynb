# %%
from sklearn import naive_bayes
import pandas as pd

# %%
data = pd.read_csv('data.csv')

# %%
X = data[["age", "spectacle_prescription", "astigmatism", "tear_production_rate"]]
Y = data[["contact_lenses"]]

# %%
NB = naive_bayes.MultinomialNB()

# %%
NB.fit(X, Y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_13620/1631965585.py in ?()
# ----> 1 NB.fit(X, Y)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1385                 skip_parameter_validation=(
#    1386                     prefer_skip_nested_validation or global_skip_validation
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/naive_bayes.py in ?(self, X, y, sample_weight)
#     731         -------
#     732         self : object
#     733             Returns the instance itself.
#     734         """
# --> 735         X, y = self._check_X_y(X, y)
#     736         _, n_features = X.shape
#     737
#     738         labelbin = LabelBinarizer()
#
# ...
