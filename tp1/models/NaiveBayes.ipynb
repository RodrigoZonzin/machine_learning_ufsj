# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# /home/rodrigo/.local/lib/python3.12/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
Ytrain  = pd.read_pickle('../data/ytrain.pkl')
Ytest   = pd.read_pickle('../data/ytest.pkl')

Xtrain  = pd.read_pickle('../data/xtrain.pkl')
Xtest   = pd.read_pickle('../data/xtest.pkl')

scaler = MinMaxScaler()
Xtrain = scaler.fit_transform(Xtrain)
Xtest = scaler.fit_transform(Xtest)

# %%
nb = GaussianNB()

# %%
nb.fit(Xtrain, Ytrain)
# Out:
# GaussianNB()

# %%
from sklearn.model_selection import cross_val_predict, cross_val_score
from sklearn.metrics import confusion_matrix, recall_score, accuracy_score, classification_report, roc_curve
from sklearn.metrics import roc_auc_score

# %%
cross_val_score(nb, Xtrain, Ytrain, cv = 5, scoring='accuracy').round(4)
# Out:
# array([0.7389, 0.7441, 0.799 , 0.7408, 0.7644])

# %%
np.mean([0.7389, 0.7441, 0.799 , 0.7408, 0.7644])
# Out:
# np.float64(0.7574400000000001)

# %%
ypred = nb.predict(Xtest)

# %%
print(classification_report(Ytest, ypred, labels=[1, 2, 3]))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.99      0.69      0.81       159
#            2       0.42      0.89      0.57        36
#            3       0.35      0.50      0.41        18
#
#     accuracy                           0.71       213
#    macro avg       0.59      0.69      0.60       213
# weighted avg       0.84      0.71      0.74       213

# %%
print(accuracy_score(Ytest, ypred), recall_score(Ytest, ypred, average='macro'))
# Out:
# 0.7089201877934272 0.693570929419986
